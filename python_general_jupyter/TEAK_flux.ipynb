# %% [markdown]
# Some global variables:

# %%
datapath = '/data'
csv = 'TEAK_2017-06.csv'

# %% [markdown]
# Import modules.

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %% [markdown]
# Read csv.

# %%
f = os.path.join(datapath, csv)
df = pd.read_csv(f, infer_datetime_format=True, index_col='timeBgn')

# %%
df.head()
# Out:
#                      Unnamed: 0  data.fluxCo2.nsae.flux  \
# timeBgn
# 2018-06-18 00:00:00           1                     NaN
# 2018-06-18 00:30:00           2                     NaN
# 2018-06-18 01:00:00           3                     NaN
# 2018-06-18 01:30:00           4                     NaN
# 2018-06-18 02:00:00           5                     NaN
#
#                      qfqm.fluxCo2.nsae.qfFinl  data.fluxTemp.nsae.flux  \
# timeBgn
# 2018-06-18 00:00:00                       NaN                      NaN
# 2018-06-18 00:30:00                       NaN                      NaN
# 2018-06-18 01:00:00                       NaN                      NaN
# 2018-06-18 01:30:00                       NaN                      NaN
# 2018-06-18 02:00:00                       NaN                      NaN
#
#                      qfqm.fluxTemp.nsae.qfFinl  data.fluxH2o.nsae.flux  \
# timeBgn
# 2018-06-18 00:00:00                        NaN                     NaN
# 2018-06-18 00:30:00                        NaN                     NaN
# 2018-06-18 01:00:00                        NaN                     NaN
# 2018-06-18 01:30:00                        NaN                     NaN
# 2018-06-18 02:00:00                        NaN                     NaN
#
#                      qfqm.fluxH2o.nsae.qfFinl  \
# timeBgn
# 2018-06-18 00:00:00                       NaN
# 2018-06-18 00:30:00                       NaN
# 2018-06-18 01:00:00                       NaN
# 2018-06-18 01:30:00                       NaN
# 2018-06-18 02:00:00                       NaN
#
#                      soilCO2concentrationMean_z501h001  \
# timeBgn
# 2018-06-18 00:00:00                             594.89
# 2018-06-18 00:30:00                             602.04
# 2018-06-18 01:00:00                             608.50
# 2018-06-18 01:30:00                             624.83
# 2018-06-18 02:00:00                             653.51
#
#                      soilCO2concentrationMinimum_z501h001  \
# timeBgn
# 2018-06-18 00:00:00                                579.63
# 2018-06-18 00:30:00                                591.72
# 2018-06-18 01:00:00                                598.89
# 2018-06-18 01:30:00                                607.65
# 2018-06-18 02:00:00                                636.40
#
#                      soilCO2concentrationMaximum_z501h001  ...  \
# timeBgn                                                    ...
# 2018-06-18 00:00:00                                604.83  ...
# 2018-06-18 00:30:00                                611.56  ...
# 2018-06-18 01:00:00                                615.94  ...
# 2018-06-18 01:30:00                                643.27  ...
# 2018-06-18 02:00:00                                672.20  ...
#
#                      soilTempStdErMean_z508h004  finalQF_z508h004  \
# timeBgn
# 2018-06-18 00:00:00                    0.000274                 0
# 2018-06-18 00:30:00                    0.000222                 0
# 2018-06-18 01:00:00                    0.000196                 0
# 2018-06-18 01:30:00                    0.000731                 0
# 2018-06-18 02:00:00                    0.000262                 0
#
#                      soilTempMean_z509h004  soilTempMinimum_z509h004  \
# timeBgn
# 2018-06-18 00:00:00                  6.159                     6.152
# 2018-06-18 00:30:00                  6.160                     6.153
# 2018-06-18 01:00:00                  6.161                     6.154
# 2018-06-18 01:30:00                  6.163                     6.133
# 2018-06-18 02:00:00                  6.164                     6.155
#
#                      soilTempMaximum_z509h004  soilTempVariance_z509h004  \
# timeBgn
# 2018-06-18 00:00:00                     6.167                   0.000011
# 2018-06-18 00:30:00                     6.167                   0.000008
# 2018-06-18 01:00:00                     6.168                   0.000007
# 2018-06-18 01:30:00                     6.186                   0.000117
# 2018-06-18 02:00:00                     6.174                   0.000014
#
#                      soilTempNumPts_z509h004  soilTempExpUncert_z509h004  \
# timeBgn
# 2018-06-18 00:00:00                    179.0                       0.139
# 2018-06-18 00:30:00                    180.0                       0.139
# 2018-06-18 01:00:00                    180.0                       0.139
# 2018-06-18 01:30:00                    180.0                       0.139
# 2018-06-18 02:00:00                    180.0                       0.139
#
#                      soilTempStdErMean_z509h004  finalQF_z509h004
# timeBgn
# 2018-06-18 00:00:00                    0.000246                 0
# 2018-06-18 00:30:00                    0.000217                 0
# 2018-06-18 01:00:00                    0.000196                 0
# 2018-06-18 01:30:00                    0.000806                 0
# 2018-06-18 02:00:00                    0.000282                 0
#
# [5 rows x 863 columns]

# %% [markdown]
# Drop points with bad qf flags for any of the data.

# %%
qfs = [col for col  in df.columns if  ('.qfFin' in col) or ('finalQF' in col)]
b4 = len(df)
df = df.loc[df[qfs].any(axis=1)]
df = df.drop(columns=qfs)
drpd = b4-len(df)
print(f'dropped {drpd} out of {b4} entries ({round(100*drpd/b4, 2)} %) due to bad QF')
# Out:
# dropped 575 out of 25152 entries (2.29 %) due to bad QF

# %% [markdown]
# ### CO2 flux

# %%
col = 'data.fluxCo2.nsae.flux'
df.plot(y=col, figsize=(14,9), style = '.');
plt.xticks(rotation=25);

# %% [markdown]
# Looks like there are outliers. lets trim them off.

# %%
# cut off data outside of 99.5%
l = df[col].quantile(0.0025)
h = df[col].quantile(0.9975)
flx = df.loc[(df[col]<h) & (df[col]>l)][col]

# plot hist
kwargs = {'bins': 40}
flx.plot(kind='hist', **kwargs);

# %%
flx.plot( figsize=(14,9), style = '.', );
plt.xticks(rotation=25);

# %% [markdown]
# ### Heat flux###

# %%
col = 'data.fluxTemp.nsae.flux'
df.plot(y=col, figsize=(14,9), style = '.');
plt.xticks(rotation=25);

# %% [markdown]
# Again, outliers.

# %%
# cut off data outside of 99.5%
l = df[col].quantile(0.0025)
h = df[col].quantile(0.9975)
flx = df.loc[(df[col]<h) & (df[col]>l)][col]

# plot hist
kwargs = {'bins': 40}
flx.plot(kind='hist', **kwargs);

# %%
flx.plot(y=col, figsize=(14,9), style = '.');
plt.xticks(rotation=25);

# %% [markdown]
# ### H2O flux

# %%
col = 'data.fluxH2o.nsae.flux'
df.plot(y=col, figsize=(14,9), style = '.');
plt.xticks(rotation=25);

# %%
# cut off data outside of 99.5%
l = df[col].quantile(0.0025)
h = df[col].quantile(0.9975)
flx = df.loc[(df[col]<h) & (df[col]>l)][col]

# plot hist
kwargs = {'bins': 40}
flx.plot(kind='hist', **kwargs);

# %%
flx.plot(y=col, figsize=(14,9), style = '.');
plt.xticks(rotation=25);

# %% [markdown]
# ### a general flux cleaning function
# For the three fluxes above trimming off the outermost 0.5% of data seems to be aresonable way of gettign rid of outliers.

# %%
def fluxtrim(df):
    '''Drops outliers by confining the flux data to the central 99.5%'''
    cols = [col for col  in df.columns if  '.nsae.flux' in col]
    for col in cols:
        l = df[col].quantile(0.0025)
        h = df[col].quantile(0.9975)
        df = df.loc[(df[col]<h) & (df[col]>l)]
        print(len(df))   
    return(df)

# %% [markdown]
# ### Soil sensor data
#
# For each sensor we have the following data:

# %%
cols = [col for col in df.columns if ('z501h001' in col) and ('CO2' in col) and (('Mean' in col) or ('Variance' in col) or ('StdErMean' in col))]
df.plot(y=cols, figsize=(14,9));

# %%
cols = [col for col in df.columns if ('z501h001' in col) and ('VSWC' in col) and (('Mean' in col) or ('Variance' in col) or ('StdErMean' in col))]
df.plot(y=cols, figsize=(14,9));

# %%
cols = [col for col in df.columns if ('z501h001' in col) and ('Temp' in col) and (('Mean' in col) or ('Variance' in col) or ('StdErMean' in col))]
df.plot(y=cols, figsize=(14,9));

# %% [markdown]
# cols = [col for col in df.columns if ('z501h001' in col) and ('CO2' in col) and (('Mean' in col) or ('Variance' in col) or ('StdErMean' in col))]
# df.plot(y=cols, figsize=(14,9));

# %%
cols = [col for col in df.columns if ('z501h001' in col) and ('VSIC' in col) and (('Mean' in col) or ('Variance' in col) or ('StdErMean' in col))]
df.plot(y=cols, figsize=(14,9));

# %% [markdown]
# For now we have no interest in the salinity (VSIC).  Also note that there quite a bit of missing data for volumetric soil water content (VSWC). Lets lokk at all depths for that sensor array.

# %%
cols = [col for col in df.columns if ('h001' in col) and ('VSWC' in col) and ('CMean' in col)]
df.plot(y=cols, figsize=(14,9));

# %% [markdown]
# Ug! Zoom in on a troublesome spot.

# %%
cols = [col for col in df.columns if ('h001' in col) and ('VSWC' in col) and ('CMean' in col)]
df.loc[df.index > '2020-06'].plot(y=cols, figsize=(14,9));

# %%
vswc_cols = [col for col in df.columns if ('z503h001' in col) and ('VSWCMean' in col)]
co2_cols = [col for col in df.columns if ('z503h001' in col) and('CO2concentrationMean' in col)]
T_cols = [col for col in df.columns if ('z503h001' in col) and('TempMean' in col)]

fig, ax = plt.subplots()
axx = ax.twinx()
axxx = ax.twinx()
df.loc[(df.index > '2018-10') & (df.index < '2019-02')].plot(ax=ax, y=vswc_cols, figsize=(14,9), color='g');
df.loc[(df.index > '2018-10') & (df.index < '2019-02')].plot(ax=axx, y=co2_cols, figsize=(14,9), color='r');
df.loc[(df.index > '2018-10') & (df.index < '2019-02')].plot(ax=axxx, y=T_cols, figsize=(14,9), color='k');

# %%
# !cp flux.ipynb /data/TEAK_flux.ipynb

# %%
for col in df.columns:
    if ('SW'  not in col) and ('CO2' not in col):
        print(col)
# Out:
# Unnamed: 0
# data.fluxCo2.nsae.flux
# data.fluxTemp.nsae.flux
# data.fluxH2o.nsae.flux
# VSICMean_z501h001
# VSICMinimum_z501h001
# VSICMaximum_z501h001
# VSICVariance_z501h001
# VSICNumPts_z501h001
# VSICExpUncert_z501h001
# VSICStdErMean_z501h001
# VSICFinalQF_z501h001
# VSICMean_z501h002
# VSICMinimum_z501h002
# VSICMaximum_z501h002
# VSICVariance_z501h002
# VSICNumPts_z501h002
# VSICExpUncert_z501h002
# VSICStdErMean_z501h002
# VSICFinalQF_z501h002
# VSICMean_z501h003
# VSICMinimum_z501h003
# VSICMaximum_z501h003
# VSICVariance_z501h003
# VSICNumPts_z501h003
# VSICExpUncert_z501h003
# VSICStdErMean_z501h003
# VSICFinalQF_z501h003
# VSICMean_z501h004
# VSICMinimum_z501h004
# VSICMaximum_z501h004
# VSICVariance_z501h004
# VSICNumPts_z501h004
# VSICExpUncert_z501h004
# VSICStdErMean_z501h004
# VSICFinalQF_z501h004
# VSICMean_z501h005
# VSICMinimum_z501h005
# VSICMaximum_z501h005
# VSICVariance_z501h005
# VSICNumPts_z501h005
# VSICExpUncert_z501h005
# VSICStdErMean_z501h005
# VSICFinalQF_z501h005
# VSICMean_z502h001
# VSICMinimum_z502h001
# VSICMaximum_z502h001
# VSICVariance_z502h001
# VSICNumPts_z502h001
# VSICExpUncert_z502h001
# VSICStdErMean_z502h001
# VSICFinalQF_z502h001
# VSICMean_z502h002
# VSICMinimum_z502h002
# VSICMaximum_z502h002
# VSICVariance_z502h002
# VSICNumPts_z502h002
# VSICExpUncert_z502h002
# VSICStdErMean_z502h002
# VSICFinalQF_z502h002
# VSICMean_z502h003
# VSICMinimum_z502h003
# VSICMaximum_z502h003
# VSICVariance_z502h003
# VSICNumPts_z502h003
# VSICExpUncert_z502h003
# VSICStdErMean_z502h003
# VSICFinalQF_z502h003
# VSICMean_z502h004
# VSICMinimum_z502h004
# VSICMaximum_z502h004
# VSICVariance_z502h004
# VSICNumPts_z502h004
# VSICExpUncert_z502h004
# VSICStdErMean_z502h004
# VSICFinalQF_z502h004
# VSICMean_z502h005
# VSICMinimum_z502h005
# VSICMaximum_z502h005
# VSICVariance_z502h005
# VSICNumPts_z502h005
# VSICExpUncert_z502h005
# VSICStdErMean_z502h005
# VSICFinalQF_z502h005
# VSICMean_z503h001
# VSICMinimum_z503h001
# VSICMaximum_z503h001
# VSICVariance_z503h001
# VSICNumPts_z503h001
# VSICExpUncert_z503h001
# VSICStdErMean_z503h001
# VSICFinalQF_z503h001
# VSICMean_z503h002
# VSICMinimum_z503h002
# VSICMaximum_z503h002
# VSICVariance_z503h002
# VSICNumPts_z503h002
# VSICExpUncert_z503h002
# VSICStdErMean_z503h002
# VSICFinalQF_z503h002
# VSICMean_z503h003
# VSICMinimum_z503h003
# VSICMaximum_z503h003
# VSICVariance_z503h003
# VSICNumPts_z503h003
# VSICExpUncert_z503h003
# VSICStdErMean_z503h003
# VSICFinalQF_z503h003
# VSICMean_z503h004
# VSICMinimum_z503h004
# VSICMaximum_z503h004
# VSICVariance_z503h004
# VSICNumPts_z503h004
# VSICExpUncert_z503h004
# VSICStdErMean_z503h004
# VSICFinalQF_z503h004
# VSICMean_z504h001
# VSICMinimum_z504h001
# VSICMaximum_z504h001
# VSICVariance_z504h001
# VSICNumPts_z504h001
# VSICExpUncert_z504h001
# VSICStdErMean_z504h001
# VSICFinalQF_z504h001
# VSICMean_z504h002
# VSICMinimum_z504h002
# VSICMaximum_z504h002
# VSICVariance_z504h002
# VSICNumPts_z504h002
# VSICExpUncert_z504h002
# VSICStdErMean_z504h002
# VSICFinalQF_z504h002
# VSICMean_z504h003
# VSICMinimum_z504h003
# VSICMaximum_z504h003
# VSICVariance_z504h003
# VSICNumPts_z504h003
# VSICExpUncert_z504h003
# VSICStdErMean_z504h003
# VSICFinalQF_z504h003
# VSICMean_z504h004
# VSICMinimum_z504h004
# VSICMaximum_z504h004
# VSICVariance_z504h004
# VSICNumPts_z504h004
# VSICExpUncert_z504h004
# VSICStdErMean_z504h004
# VSICFinalQF_z504h004
# VSICMean_z505h001
# VSICMinimum_z505h001
# VSICMaximum_z505h001
# VSICVariance_z505h001
# VSICNumPts_z505h001
# VSICExpUncert_z505h001
# VSICStdErMean_z505h001
# VSICFinalQF_z505h001
# VSICMean_z505h002
# VSICMinimum_z505h002
# VSICMaximum_z505h002
# VSICVariance_z505h002
# VSICNumPts_z505h002
# VSICExpUncert_z505h002
# VSICStdErMean_z505h002
# VSICFinalQF_z505h002
# VSICMean_z505h003
# VSICMinimum_z505h003
# VSICMaximum_z505h003
# VSICVariance_z505h003
# VSICNumPts_z505h003
# VSICExpUncert_z505h003
# VSICStdErMean_z505h003
# VSICFinalQF_z505h003
# VSICMean_z505h004
# VSICMinimum_z505h004
# VSICMaximum_z505h004
# VSICVariance_z505h004
# VSICNumPts_z505h004
# VSICExpUncert_z505h004
# VSICStdErMean_z505h004
# VSICFinalQF_z505h004
# VSICMean_z506h001
# VSICMinimum_z506h001
# VSICMaximum_z506h001
# VSICVariance_z506h001
# VSICNumPts_z506h001
# VSICExpUncert_z506h001
# VSICStdErMean_z506h001
# VSICFinalQF_z506h001
# VSICMean_z506h002
# VSICMinimum_z506h002
# VSICMaximum_z506h002
# VSICVariance_z506h002
# VSICNumPts_z506h002
# VSICExpUncert_z506h002
# VSICStdErMean_z506h002
# VSICFinalQF_z506h002
# VSICMean_z506h004
# VSICMinimum_z506h004
# VSICMaximum_z506h004
# VSICVariance_z506h004
# VSICNumPts_z506h004
# VSICExpUncert_z506h004
# VSICStdErMean_z506h004
# VSICFinalQF_z506h004
# VSICMean_z507h002
# VSICMinimum_z507h002
# VSICMaximum_z507h002
# VSICVariance_z507h002
# VSICNumPts_z507h002
# VSICExpUncert_z507h002
# VSICStdErMean_z507h002
# VSICFinalQF_z507h002
# VSICMean_z507h004
# VSICMinimum_z507h004
# VSICMaximum_z507h004
# VSICVariance_z507h004
# VSICNumPts_z507h004
# VSICExpUncert_z507h004
# VSICStdErMean_z507h004
# VSICFinalQF_z507h004
# VSICMean_z508h002
# VSICMinimum_z508h002
# VSICMaximum_z508h002
# VSICVariance_z508h002
# VSICNumPts_z508h002
# VSICExpUncert_z508h002
# VSICStdErMean_z508h002
# VSICFinalQF_z508h002
# VSICMean_z508h004
# VSICMinimum_z508h004
# VSICMaximum_z508h004
# VSICVariance_z508h004
# VSICNumPts_z508h004
# VSICExpUncert_z508h004
# VSICStdErMean_z508h004
# VSICFinalQF_z508h004
# soilTempMean_z501h001
# soilTempMinimum_z501h001
# soilTempMaximum_z501h001
# soilTempVariance_z501h001
# soilTempNumPts_z501h001
# soilTempExpUncert_z501h001
# soilTempStdErMean_z501h001
# soilTempMean_z501h002
# soilTempMinimum_z501h002
# soilTempMaximum_z501h002
# soilTempVariance_z501h002
# soilTempNumPts_z501h002
# soilTempExpUncert_z501h002
# soilTempStdErMean_z501h002
# soilTempMean_z501h003
# soilTempMinimum_z501h003
# soilTempMaximum_z501h003
# soilTempVariance_z501h003
# soilTempNumPts_z501h003
# soilTempExpUncert_z501h003
# soilTempStdErMean_z501h003
# soilTempMean_z501h004
# soilTempMinimum_z501h004
# soilTempMaximum_z501h004
# soilTempVariance_z501h004
# soilTempNumPts_z501h004
# soilTempExpUncert_z501h004
# soilTempStdErMean_z501h004
# soilTempMean_z501h005
# soilTempMinimum_z501h005
# soilTempMaximum_z501h005
# soilTempVariance_z501h005
# soilTempNumPts_z501h005
# soilTempExpUncert_z501h005
# soilTempStdErMean_z501h005
# soilTempMean_z502h001
# soilTempMinimum_z502h001
# soilTempMaximum_z502h001
# soilTempVariance_z502h001
# soilTempNumPts_z502h001
# soilTempExpUncert_z502h001
# soilTempStdErMean_z502h001
# soilTempMean_z502h002
# soilTempMinimum_z502h002
# soilTempMaximum_z502h002
# soilTempVariance_z502h002
# soilTempNumPts_z502h002
# soilTempExpUncert_z502h002
# soilTempStdErMean_z502h002
# soilTempMean_z502h003
# soilTempMinimum_z502h003
# soilTempMaximum_z502h003
# soilTempVariance_z502h003
# soilTempNumPts_z502h003
# soilTempExpUncert_z502h003
# soilTempStdErMean_z502h003
# soilTempMean_z502h004
# soilTempMinimum_z502h004
# soilTempMaximum_z502h004
# soilTempVariance_z502h004
# soilTempNumPts_z502h004
# soilTempExpUncert_z502h004
# soilTempStdErMean_z502h004
# soilTempMean_z502h005
# soilTempMinimum_z502h005
# soilTempMaximum_z502h005
# soilTempVariance_z502h005
# soilTempNumPts_z502h005
# soilTempExpUncert_z502h005
# soilTempStdErMean_z502h005
# soilTempMean_z503h001
# soilTempMinimum_z503h001
# soilTempMaximum_z503h001
# soilTempVariance_z503h001
# soilTempNumPts_z503h001
# soilTempExpUncert_z503h001
# soilTempStdErMean_z503h001
# soilTempMean_z503h002
# soilTempMinimum_z503h002
# soilTempMaximum_z503h002
# soilTempVariance_z503h002
# soilTempNumPts_z503h002
# soilTempExpUncert_z503h002
# soilTempStdErMean_z503h002
# soilTempMean_z503h003
# soilTempMinimum_z503h003
# soilTempMaximum_z503h003
# soilTempVariance_z503h003
# soilTempNumPts_z503h003
# soilTempExpUncert_z503h003
# soilTempStdErMean_z503h003
# soilTempMean_z503h004
# soilTempMinimum_z503h004
# soilTempMaximum_z503h004
# soilTempVariance_z503h004
# soilTempNumPts_z503h004
# soilTempExpUncert_z503h004
# soilTempStdErMean_z503h004
# soilTempMean_z503h005
# soilTempMinimum_z503h005
# soilTempMaximum_z503h005
# soilTempVariance_z503h005
# soilTempNumPts_z503h005
# soilTempExpUncert_z503h005
# soilTempStdErMean_z503h005
# soilTempMean_z504h001
# soilTempMinimum_z504h001
# soilTempMaximum_z504h001
# soilTempVariance_z504h001
# soilTempNumPts_z504h001
# soilTempExpUncert_z504h001
# soilTempStdErMean_z504h001
# soilTempMean_z504h002
# soilTempMinimum_z504h002
# soilTempMaximum_z504h002
# soilTempVariance_z504h002
# soilTempNumPts_z504h002
# soilTempExpUncert_z504h002
# soilTempStdErMean_z504h002
# soilTempMean_z504h003
# soilTempMinimum_z504h003
# soilTempMaximum_z504h003
# soilTempVariance_z504h003
# soilTempNumPts_z504h003
# soilTempExpUncert_z504h003
# soilTempStdErMean_z504h003
# soilTempMean_z504h004
# soilTempMinimum_z504h004
# soilTempMaximum_z504h004
# soilTempVariance_z504h004
# soilTempNumPts_z504h004
# soilTempExpUncert_z504h004
# soilTempStdErMean_z504h004
# soilTempMean_z504h005
# soilTempMinimum_z504h005
# soilTempMaximum_z504h005
# soilTempVariance_z504h005
# soilTempNumPts_z504h005
# soilTempExpUncert_z504h005
# soilTempStdErMean_z504h005
# soilTempMean_z505h001
# soilTempMinimum_z505h001
# soilTempMaximum_z505h001
# soilTempVariance_z505h001
# soilTempNumPts_z505h001
# soilTempExpUncert_z505h001
# soilTempStdErMean_z505h001
# soilTempMean_z505h002
# soilTempMinimum_z505h002
# soilTempMaximum_z505h002
# soilTempVariance_z505h002
# soilTempNumPts_z505h002
# soilTempExpUncert_z505h002
# soilTempStdErMean_z505h002
# soilTempMean_z505h003
# soilTempMinimum_z505h003
# soilTempMaximum_z505h003
# soilTempVariance_z505h003
# soilTempNumPts_z505h003
# soilTempExpUncert_z505h003
# soilTempStdErMean_z505h003
# soilTempMean_z505h004
# soilTempMinimum_z505h004
# soilTempMaximum_z505h004
# soilTempVariance_z505h004
# soilTempNumPts_z505h004
# soilTempExpUncert_z505h004
# soilTempStdErMean_z505h004
# soilTempMean_z506h001
# soilTempMinimum_z506h001
# soilTempMaximum_z506h001
# soilTempVariance_z506h001
# soilTempNumPts_z506h001
# soilTempExpUncert_z506h001
# soilTempStdErMean_z506h001
# soilTempMean_z506h002
# soilTempMinimum_z506h002
# soilTempMaximum_z506h002
# soilTempVariance_z506h002
# soilTempNumPts_z506h002
# soilTempExpUncert_z506h002
# soilTempStdErMean_z506h002
# soilTempMean_z506h004
# soilTempMinimum_z506h004
# soilTempMaximum_z506h004
# soilTempVariance_z506h004
# soilTempNumPts_z506h004
# soilTempExpUncert_z506h004
# soilTempStdErMean_z506h004
# soilTempMean_z507h001
# soilTempMinimum_z507h001
# soilTempMaximum_z507h001
# soilTempVariance_z507h001
# soilTempNumPts_z507h001
# soilTempExpUncert_z507h001
# soilTempStdErMean_z507h001
# soilTempMean_z507h002
# soilTempMinimum_z507h002
# soilTempMaximum_z507h002
# soilTempVariance_z507h002
# soilTempNumPts_z507h002
# soilTempExpUncert_z507h002
# soilTempStdErMean_z507h002
# soilTempMean_z507h004
# soilTempMinimum_z507h004
# soilTempMaximum_z507h004
# soilTempVariance_z507h004
# soilTempNumPts_z507h004
# soilTempExpUncert_z507h004
# soilTempStdErMean_z507h004
# soilTempMean_z508h001
# soilTempMinimum_z508h001
# soilTempMaximum_z508h001
# soilTempVariance_z508h001
# soilTempNumPts_z508h001
# soilTempExpUncert_z508h001
# soilTempStdErMean_z508h001
# soilTempMean_z508h002
# soilTempMinimum_z508h002
# soilTempMaximum_z508h002
# soilTempVariance_z508h002
# soilTempNumPts_z508h002
# soilTempExpUncert_z508h002
# soilTempStdErMean_z508h002
# soilTempMean_z508h004
# soilTempMinimum_z508h004
# soilTempMaximum_z508h004
# soilTempVariance_z508h004
# soilTempNumPts_z508h004
# soilTempExpUncert_z508h004
# soilTempStdErMean_z508h004
# soilTempMean_z509h004
# soilTempMinimum_z509h004
# soilTempMaximum_z509h004
# soilTempVariance_z509h004
# soilTempNumPts_z509h004
# soilTempExpUncert_z509h004
# soilTempStdErMean_z509h004
